# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Online_Store.csv', encoding="ISO-8859-1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE            463 non-null    object
#  1   USER_ID         463 non-null    object
#  2   AGE             463 non-null    int64
#  3   GENDER          463 non-null    object
#  4   TYPE            347 non-null    float64
#  5   CREDIT_SCORE    463 non-null    int64
#  6   LIFETIME        463 non-null    int64
#  7   PAYMENT_METHOD  463 non-null    object
#  8   TURNOVER        463 non-null    int64
#  9   SENDBACK        463 non-null    bool
#  10  VIDEO_AD        463 non-null    bool
#  11  CONVERTED       463 non-null    int64
# dtypes: bool(2), float64(1), int64(5), object(4)
# memory usage: 37.2+ KB

# %%
df.head()
# Out:
#          DATE           USER_ID  AGE  GENDER  TYPE  CREDIT_SCORE  LIFETIME  \
# 0  2023-10-02            cardiB   27  female   NaN             3         8
# 1  2023-10-02  natalie_hershlag   42  female   NaN             4        10
# 2  2023-10-02         babe_ruth   48    male   1.0             2        12
# 3  2023-10-02  homlesspistachio   60    male   1.0             5         9
# 4  2023-10-02    chrstian_hauff   93    male   1.0             5        12
#
#   PAYMENT_METHOD  TURNOVER  SENDBACK  VIDEO_AD  CONVERTED
# 0  bank transfer        44     False     False          0
# 1           BNPL        34     False     False          0
# 2           BNPL        34     False     False          0
# 3         paypal       500     False     False          0
# 4    credit card        43     False      True          0

# %%
df = df.drop("USER_ID",axis=1)

# %%
df = df.drop("DATE",axis=1)

# %%
df = df.drop("SENDBACK",axis=1)

# %%
df = df.drop("VIDEO_AD",axis=1)

# %%
df.head()
# Out:
#    AGE  GENDER  TYPE  CREDIT_SCORE  LIFETIME PAYMENT_METHOD  TURNOVER  \
# 0   27  female   NaN             3         8  bank transfer        44
# 1   42  female   NaN             4        10           BNPL        34
# 2   48    male   1.0             2        12           BNPL        34
# 3   60    male   1.0             5         9         paypal       500
# 4   93    male   1.0             5        12    credit card        43
#
#    CONVERTED
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df['PAYMENT_METHOD'].value_counts()
# Out:
# BNPL             174
# bank transfer    109
# paypal           102
# credit card       78
# Name: PAYMENT_METHOD, dtype: int64

# %%
# Convert categorical columns to numerical values
df['GENDER'] = df['GENDER'].map({'male': 0, 'female': 1})
df['PAYMENT_METHOD'] = df['PAYMENT_METHOD'].map({'bank transfer': 0, 'BNPL': 1, 'paypal':2,'credit card':3})
print('GENDER:', df['GENDER'].nunique(), df['GENDER'].unique())
print('PAYMENT_METHOD:', df['PAYMENT_METHOD'].nunique(), df['PAYMENT_METHOD'].unique())
# Out:
# GENDER: 2 [1 0]
# PAYMENT_METHOD: 4 [0 1 2 3]

# %%
df.isnull().sum()
# Out:
# AGE                 0
# GENDER              0
# TYPE              116
# CREDIT_SCORE        0
# LIFETIME            0
# PAYMENT_METHOD      0
# TURNOVER            0
# CONVERTED           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
numerical_cols = ['TYPE']
imputer = SimpleImputer(strategy='median')
df[numerical_cols] = imputer.fit_transform(df[numerical_cols])

# %%
df.isnull().sum()
# Out:
# AGE               0
# GENDER            0
# TYPE              0
# CREDIT_SCORE      0
# LIFETIME          0
# PAYMENT_METHOD    0
# TURNOVER          0
# CONVERTED         0
# dtype: int64

# %%
df.describe()
# Out:
#               AGE      GENDER        TYPE  CREDIT_SCORE    LIFETIME  \
# count  463.000000  463.000000  463.000000    463.000000  463.000000
# mean    42.924406    0.334773    1.073434      3.764579    8.820734
# std     15.363303    0.472422    0.261130      1.119813    3.504518
# min     21.000000    0.000000    1.000000      1.000000    0.000000
# 25%     30.000000    0.000000    1.000000      3.000000    8.000000
# 50%     38.000000    0.000000    1.000000      4.000000   10.000000
# 75%     53.000000    1.000000    1.000000      5.000000   12.000000
# max     93.000000    1.000000    2.000000      5.000000   12.000000
#
#        PAYMENT_METHOD    TURNOVER   CONVERTED
# count      463.000000  463.000000  463.000000
# mean         1.321814  182.103672    0.174946
# std          1.014025  192.668002    0.380332
# min          0.000000   31.000000    0.000000
# 25%          1.000000   39.000000    0.000000
# 50%          1.000000   48.000000    0.000000
# 75%          2.000000  346.500000    0.000000
# max          3.000000  718.000000    1.000000

# %%
plt.figure(figsize=(10, 8))  
sns.heatmap(df.corr(numeric_only=True), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.plot(kind = 'box', figsize = (16, 16), layout = (6, 3), sharex = False, subplots = True);

# %%
X = df.drop('CONVERTED',axis=1)
y = df['CONVERTED']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

df.to_csv("data_cleaned.csv", sep=",", index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, roc_curve, auc

# %%
print("Random Forest")
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# Random Forest
# RandomForestClassifier(random_state=42)

# %%
def evaluate_model(model,X_train, y_train, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    # Predictions on training set for ROC curve
    y_pred_train_proba = model.predict_proba(X_train)[:, 1]
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
 
    roc_auc = roc_auc_score(y_test, y_pred)
       
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'ROC AUC Score: {roc_auc:.4f}')
    
    # ROC Curve for Testing Dataset
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
evaluate_model(rf_model, X_train, y_train, X_test, y_test)
# Out:
# Accuracy: 0.7742
# Precision: 0.4286
# Recall: 0.1500
# ROC AUC Score: 0.5476
